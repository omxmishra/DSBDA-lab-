# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in c:\programdata\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: click in c:\programdata\anaconda3\lib\site-packages (from nltk) (8.2.1)
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\programdata\anaconda3\lib\site-packages (from nltk) (2025.9.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Om
# [nltk_data]     Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Om
# [nltk_data]     Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Om Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to C:\Users\Om
# [nltk_data]     Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\Om
# [nltk_data]     Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Om Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Om Mishra\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tokens = text.split()
tokens
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'is',
#  'a',
#  'field',
#  'of',
#  'Artificial',
#  'Intelligence',
#  'that',
#  'deals',
#  'with',
#  'text',
#  'data.']

# %%
pos_tags = [(word, "NN") for word in tokens]
pos_tags
# Out:
# [('Natural', 'NN'),
#  ('Language', 'NN'),
#  ('Processing', 'NN'),
#  ('is', 'NN'),
#  ('a', 'NN'),
#  ('field', 'NN'),
#  ('of', 'NN'),
#  ('Artificial', 'NN'),
#  ('Intelligence', 'NN'),
#  ('that', 'NN'),
#  ('deals', 'NN'),
#  ('with', 'NN'),
#  ('text', 'NN'),
#  ('data.', 'NN')]

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [w for w in tokens if w.lower() not in stop_words]
filtered_tokens
# Out:
# ['Natural',
#  'Language',
#  'Processing',
#  'field',
#  'Artificial',
#  'Intelligence',
#  'deals',
#  'text',
#  'data.']

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
stemmed = [stemmer.stem(w) for w in filtered_tokens]
lemmatized = [lemmatizer.lemmatize(w) for w in filtered_tokens]
print("Stemmed:", stemmed)
print("Lemmatized:", lemmatized)
# Out:
# Stemmed: ['natur', 'languag', 'process', 'field', 'artifici', 'intellig', 'deal', 'text', 'data.']
# Lemmatized: ['Natural', 'Language', 'Processing', 'field', 'Artificial', 'Intelligence', 'deal', 'text', 'data.']

# %%
from collections import Counter
tf = Counter(filtered_tokens)
tf
# Out:
# Counter({'Natural': 1,
#          'Language': 1,
#          'Processing': 1,
#          'field': 1,
#          'Artificial': 1,
#          'Intelligence': 1,
#          'deals': 1,
#          'text': 1,
#          'data.': 1})

# %%
clean_tokens = [w.lower().strip('.,') for w in filtered_tokens]
clean_tokens
# Out:
# ['natural',
#  'language',
#  'processing',
#  'field',
#  'artificial',
#  'intelligence',
#  'deals',
#  'text',
#  'data']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
doc = " ".join(clean_tokens)
vectorizer = TfidfVectorizer()
tfidf = vectorizer.fit_transform([doc])
print("Words:", vectorizer.get_feature_names_out())
print("TF-IDF:\n", tfidf.toarray())
# Out:
# Words: ['artificial' 'data' 'deals' 'field' 'intelligence' 'language' 'natural'
#  'processing' 'text']
# TF-IDF:
#  [[0.33333333 0.33333333 0.33333333 0.33333333 0.33333333 0.33333333
#   0.33333333 0.33333333 0.33333333]]
